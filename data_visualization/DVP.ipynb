# %%
## Line plot with matplotlib

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
d = pd.read_csv('C:/Users/Gulfam/Desktop/Data Sci/data_visualization/Sample - Superstore_Orders.csv')

# %%
d.columns
# Out:
# Index(['Category', 'City', 'Country/Region', 'Customer Name', 'Manufacturer',
#        'Order Date', 'Order ID', 'Postal Code', 'Product Name', 'Region',
#        'Segment', 'Ship Date', 'Ship Mode', 'State', 'Sub-Category',
#        'Discount', 'Profit', 'Quantity', 'Sales'],
#       dtype='object')

# %%
x = d['Sales']
y = d['Discount']

# %%
plt.scatter(x,y, linewidth = 1.0)
plt.xlabel('sales')
# Out:
# Text(0.5, 0, 'sales')

# %%
x = np.linspace(0,10,100)

# %%
y = 4 + 2 * np.sin(2 * x)

# %%
plt.style.use('_mpl-gallery')
plt.plot(x,y)
